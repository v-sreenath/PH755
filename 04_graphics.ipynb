# %% [markdown]
# # Graphics using Matplotlib

# %%
import numpy as np # import numpy to handle data
import matplotlib.pyplot as plt # import pyplot for plotting
# %matplotlib inline

# %%
# Create two arrays
a = np.arange(0,10,1/5)
b = a**2

# %%
# Plot a on x-axis and b on y-axis
plt.plot(a,b)

# %% [markdown]
# ### Features in plot
# One could add several features to the plot to make it more comprehensible.
#
# * `linestyle` :
#     - '-' for line
#     - '--' for dashed
#     - '-.' for dash dotted
#     - ':' for dotted
#
# * `color` : Matplotlib has a host of colors to choose from
#
# * `marker` :
#     - 'o' dot
#     - 's' square
#     - 'v' for downward triangle
#     - '^' for upward triangle
#
# * `marker` has various attributes:
#     - `markerfacecolor' choose color of the face of marker
#     - `markeredgewidth` set it to zero to remove edge of a marker
#     - `markersize` set it to a particular size
#
# * `label` to choose the name that appears in the legend. Use r before single quote if using Latex.
#
# * `plt.xlabel` chooses x-label
#
# * `plt.ylabel` chooses y-label
#
# * `plt.legend` to show the legend and fix its properties:
#     - `loc` : location
#     - `numpoints` : number of points that appear in the legend
#     - `ncol` : number of columns
#     - `shadow` : shadow of legend box if `frameon` is True
#     - `frameon` : Whether to put a box around legend
#     - `prop={size:12}` : To choose font size in legend

# %%
plt.plot(a,b, linestyle='-', color='k', 
         marker='o',markerfacecolor='c',markeredgewidth=.0,markersize=6., label=r'$n\,=\,2$')
plt.plot(a,a**3, linestyle='-', color='b', linewidth=2,
         marker='s',markerfacecolor='red',markeredgewidth=.0,markersize=6., label= r'$n\, =\, 3$')
plt.annotate("Point x=6",xy=(6,216),xytext=(7,216),arrowprops=dict(arrowstyle="->", connectionstyle="arc3"))
plt.annotate("Point x=6",xy=(6,36),xytext=(7,216),arrowprops=dict(arrowstyle="->", connectionstyle="arc3"))
plt.xlabel(r"Numbers ($x$)")
plt.ylabel(r"Square of Numbers ($x^n$)")
plt.legend(loc='best',numpoints = 1,ncol =1, shadow=False,frameon=True,prop={'size':12})

# %%
data=np.loadtxt('LOAD YOUR DATA HERE')
# Try plotting some data

# %%
plt.plot(data[:,0],data[:,1],linestyle='-',marker='o',markerfacecolor='r',
         markeredgewidth=0.0, markersize=5)
plt.xlabel(r'$\ell$',fontsize=20)
plt.ylabel(r'$D_\ell^{TT}$',fontsize=20)
# Out:
# (0, 500)

# %% [markdown]
# ## Explore the following:
#
# `plt.xlim([starting range,end range])`
#
# `plt.ylim([starting range,end range])`
#
# `plt.xscale('log') `
#
# `plt.yscale('symlog')`

# %% [markdown]
# ## For more resources, see:
#
# - [Tutorials](https://matplotlib.org/stable/tutorials/index.html#introductory)
# - [Gallery](https://matplotlib.org/stable/gallery/index.html)
# - [Sample plots](https://matplotlib.org/stable/tutorials/introductory/sample_plots.html)
# - [3D plots](https://matplotlib.org/mpl_toolkits/mplot3d/tutorial.html)
# - [animations](https://jakevdp.github.io/blog/2012/08/18/matplotlib-animation-tutorial/)
